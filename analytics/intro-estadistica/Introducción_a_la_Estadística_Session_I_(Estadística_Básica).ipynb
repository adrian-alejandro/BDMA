# %% [markdown]
# <a href="https://colab.research.google.com/github/adrian-alejandro/BDMA/blob/main/analytics/intro-estadistica/Introducci%C3%B3n_a_la_Estad%C3%ADstica_Session_I_(Estad%C3%ADstica_B%C3%A1sica).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Integrantes:

# %% [markdown]
# ## SESIÓN 1: ESTADÍSTICA BÁSICA

# %% [markdown]
# #### 1. Calcular la media, la mediana, la desviación tipo, el primer cuartil, el tercer cuartil, el rango intercuartílico y dibujar el correspondiente boxplot, de la siguiente muestra de precios de pisos (de 3 habitaciones): 7.80, 12.60, 15.96, 13.50, 8.25, 31.29, 16.46

# %%
# Armamos el vector con la muestra de precios
muestra_de_precios <- c(7.80, 12.60, 15.96, 13.50, 8.25, 31.29, 16.46)

muestra_de_precios
# Out:
# [1]  7.80 12.60 15.96 13.50  8.25 31.29 16.46

# %%
# Realizamos una descripción numérica de nuestra variable usando 'summary',
# que nos brinda los siguientes estadísticos: Mínimo, 1er cuartil, mediana, media, tercer cuartil y el máximo
summary(muestra_de_precios)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    7.80   10.43   13.50   15.12   16.21   31.29

# %%
# Ahora calculamos el rango intercuartílico:
Q3 <- as.numeric(summary(muestra_de_precios)[5])
Q1 <- as.numeric(summary(muestra_de_precios)[2])

IQR <- Q3 - Q1

cat("El rango intercuartílico de la muestra es: ",IQR)
# Out:
# El rango intercuartílico de la muestra es:  5.785

# %%
# Ahora graficaremos el correspondiente boxplot
boxplot(muestra_de_precios,
        data=muestra_de_precios,
        main="Precios de pisos (de 3 habitaciones)",
        horizontal=TRUE,
        las=2,
        ylab="",
        xlab="Precio (Millones)")
# Out:
# Plot with title “Precios de pisos (de 3 habitaciones)”

# %% [markdown]
# #### 2. Diga qué razones le parecen convincentes para justificar que la media de una muestra escogida al azar es un estimador más fiable que la media de una muestra de expertos.

# %% [markdown]
# La media de una muestra escogida al azar es un estimador más fiable que la media de una muestra de expertos, dado que estos últimos pueden introducir sesgos. De esta forma, para asegurarnos de que esto no ocurra, la muestra tiene que ser diversa (y representativa) y que los puntos/observaciones de la muestra sean independientes entre sí.

# %% [markdown]
# #### 3. Suponga la variable aleatoria “tiempo que tardo en ir de mi casa al trabajo” y diferencie factores sistemáticos y factores aleatorios intervinientes en su medición.

# %% [markdown]
# - Factores sistemáticos:
#     - Distancia entre mi casa y el trabajo (es importante y mesurable)
#     - Frecuencia del metro (es importante y mesurable)
# - Factores aleatorios:
#     - Estado de las vías / problemas técnicos del metro
#     - Cantidad de gente que tengo que cruzar/esquivar entre el trayecto de mi casa a la puerta del metro

# %% [markdown]
# #### 4. ¿Cuándo podemos asegurar que el mecanismo generador de una variable aleatoria se aproxima a una distribución gaussiana?

# %% [markdown]
# Según el Teorema Central del Límite, el mecanismo generador de una variable aleatoria se aproxima a una distribución gaussiana si hay muchos factores irrelevantes (de poca importancia) y a su vez todos estos tienen una importancia similar.

# %% [markdown]
# #### 4. Lea el fichero “BCN_pisos.txt”. Efectúe un summary de las variables leídas. Detecte si en el fichero proporcionado hay registros duplicados y elimínelos. Los datos proporcionados son reales. ¿Por qué cree que existen registros duplicados?

# %%
# Primero importamos la data
bcn_pisos <- read.table("bcn_pisos.txt", header=TRUE)

# Visualizamos los primeros registros de nuestra muestra
head(bcn_pisos)
# Out:
#   Valor    Superf Dorm Banys Edat Estat Planta Dist         ValSol    Tipus
# 1  4962780 31.41  2    1      70  1_MM  Planta Ciutat_Vella 113322.15 MANZ
# 2  7001400 42.00  1    1     100  2_M   Planta Ciutat_Vella  89407.53 MANZ
# 3  8283600 42.48  2    1      80  2_M   Planta Ciutat_Vella 122622.28 MANZ
# 4 10248000 61.00  3    1     100  1_MM  Planta Ciutat_Vella 105350.61 MANZ
# 5 19566720 96.00  2    2       0  5_MB  Planta Ciutat_Vella  86750.35 MANZ
# 6  9575648 76.30  2    1     113  1_MM  Atic   Ciutat_Vella  73464.45 MANZ
#   Ascens ExtInt Reforma
# 1 NO     EXT    REF15-20
# 2 NO     EXT    REF1A5
# 3 NO     EXT    RECIENREF
# 4 SI     EXT    RECIENREF
# 5 SI     EXT    OBRANUEVA
# 6 NO     EXT    REF10-15

# %%
# Efectuamos un summary de las variables leídas:
summary(bcn_pisos)
# Out:
#      Valor              Superf            Dorm           Banys
#  Min.   : 3007368   Min.   : 23.24   Min.   :1.000   Min.   :1.000
#  1st Qu.:12025000   1st Qu.: 64.20   1st Qu.:2.000   1st Qu.:1.000
#  Median :15456000   Median : 78.54   Median :3.000   Median :1.000
#  Mean   :17823727   Mean   : 83.97   Mean   :2.903   Mean   :1.319
#  3rd Qu.:20920248   3rd Qu.: 95.00   3rd Qu.:3.000   3rd Qu.:2.000
#  Max.   :99662144   Max.   :475.30   Max.   :5.000   Max.   :4.000
#       Edat           Estat              Planta              Dist
#  Min.   :  0.00   Length:2329        Length:2329        Length:2329
#  1st Qu.: 25.00   Class :character   Class :character   Class :character
#  Median : 30.00   Mode  :character   Mode  :character   Mode  :character
#  Mean   : 40.75
#  3rd Qu.: 50.00
#  Max.   :289.00
#      ValSol          Tipus              Ascens             ExtInt
#  Min.   : 20321   Length:2329        Length:2329        Length:2329
#  1st Qu.:106679   Class :character   Class :character   Class :character
#  Median :119965   Mode  :character   Mode  :character   Mode  :character
#  Mean   :128708
#  3rd Qu.:146537
#  Max.   :365754
#    Reforma
#  Length:2329
#  Class :character
#  Mode  :character

# %%
# Ahora analizamos los duplicados
bcn_pisos_duplicados <- bcn_pisos[duplicated(bcn_pisos), ]

cat("Vemos que hay ", nrow(bcn_pisos_duplicados), " pisos duplicados:\n")

head(bcn_pisos_duplicados)
# Out:
# Vemos que hay  75  pisos duplicados:
#     Valor    Superf Dorm Banys Edat Estat Planta Dist         ValSol   Tipus
# 43  26130064 135.0  4    2     98   3_N   Planta Ciutat_Vella 132321.0 MANZ
# 49  12749000  67.1  3    1     32   3_N   Planta Ciutat_Vella 119965.1 MANZ
# 151  6300000  36.0  1    1     70   1_MM  Bajos  Ciutat_Vella 113322.1 BLOQ
# 222 17922000  87.0  3    1     32   3_N   Planta Sants        126608.1 MANZ
# 280 15307600  78.1  3    1     25   2_M   Atic   Sants        123950.9 MANZ
# 362 19000000 100.0  4    1     50   1_MM  Planta Sarria       146536.9 MANZ
#     Ascens ExtInt Reforma
# 43  NO     EXT    RECIENREF
# 49  SI     EXT    REF1A5
# 151 NO     EXT    SINREFORMA
# 222 SI     INT    REF1A5
# 280 SI     EXT    SINREFORMA
# 362 NO     EXT    SINREFORMA

# %% [markdown]
# Una razón que pueda explicar que haya registros duplicados puede ser de que el derecho de venta lo tengan varias inmobiliarias que publiquen por separado el piso. También puede ser porque los pisos no se vendan y se republique el aviso.

# %%
# Removemos los duplicados
bcn_pisos <- bcn_pisos[!duplicated(bcn_pisos),]

# %% [markdown]
# #### 6. Represente gráficamente la distribución de cada variable del fichero: histograma o función de densidad para las variables continuas o diagrama de barras para las variables categóricas.

# %% [markdown]
# Graficamos las variables continuas:

# %%
# Valor
hist(bcn_pisos$Valor,
     xlab = "Valor",
     ylab="Frecuencia",
     breaks=50,
     main = "Histograma de la variable 'Valor'")

# Superficie
hist(bcn_pisos$Superf,
     xlab = "Superficie",
     ylab="Frecuencia",
     breaks=50,
     main = "Histograma de la variable 'Superf' (Superficie)",
     xlim = c(0, 1.1*max(bcn_pisos$Superf)))

# Antigüedad
hist(bcn_pisos$Edat,
     xlab = "Antigüedad",
     ylab="Frecuencia",
     breaks=25,
     main = "Histograma de la variable 'Edat' (Antigüedad)")

# Valsol
hist(bcn_pisos$ValSol,
     xlab = "Valsol",
     ylab="Frecuencia",
     breaks=25,
     main = "Histograma de la variable 'Valsol'",
     xlim = c(0, 1.1*max(bcn_pisos$ValSol)))
# Out:
# Plot with title “Histograma de la variable 'Valor'”
# Plot with title “Histograma de la variable 'Superf' (Superficie)”
# Plot with title “Histograma de la variable 'Edat' (Antigüedad)”
# Plot with title “Histograma de la variable 'Valsol'”

# %% [markdown]
# Graficamos las variables categóricas:

# %%
# Importamos librerías para darle color a los diagramas
library(RColorBrewer)
colors <- brewer.pal(nlevels(as.factor(bcn_pisos$Dorm)), "Paired")

# Número de dormitorios
barplot(table(bcn_pisos$Dorm),
        col='orange',
        border = "white",
        main = "Número de dormitorios")

# Número de baños
barplot(table(bcn_pisos$Banys),
        col='seagreen',
        border = "white",
        main = "Número de Baños")

# Estado del inmueble
barplot(table(bcn_pisos$Estat),
        col='hotpink',
        border = "white",
        main = "Estado del inmueble")

# Tipo de Planta
barplot(table(bcn_pisos$Planta),
        col='slategrey',
        border = "white",
        main = "Tipo de Planta")

# Distrito
barplot(table(bcn_pisos$Dist),
        col='brown',
        border = "white",
        las=1,
        horiz=TRUE,
        cex.names=0.6,
        main = "Distrito")

# Tipus
barplot(table(bcn_pisos$Tipus),
        col='darkorchid',
        border = "white",
        main = "Tipus")

# Ascens
barplot(table(bcn_pisos$Ascens),
        col='darkkhaki',
        border = "white",
        main = "Ascensor")

# ExtInt
barplot(table(bcn_pisos$ExtInt),
        col='gold',
        border = "white",
        main = "Exterior / Interior")

# Reforma
barplot(table(bcn_pisos$Reforma),
        col='cadetblue',
        border = "white",
        las=1,
        horiz=TRUE,
        cex.names=0.6,
        main = "Reforma")
# Out:
# Plot with title “Número de dormitorios”
# Plot with title “Número de Baños”
# Plot with title “Estado del inmueble”
# Plot with title “Tipo de Planta”
# Plot with title “Distrito”
# Plot with title “Tipus”
# Plot with title “Ascensor”
# Plot with title “Exterior / Interior”
# Plot with title “Reforma”

# %% [markdown]
# #### 7. Identifique si existe algún piso que podemos considerar “outlier” (para ello sólo tenga en cuenta las variables continuas). Elimínelo del data frame.

# %% [markdown]
# Para determinar los outliers de la muestra recurriremos al método LOF (Local Outlier Factor), el cual detecta potenciales outliers basándose en la densidad local de los puntos de la muestra.

# %%
install.packages("DescTools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Rcpp’, ‘Exact’, ‘gld’

# %%
library(DescTools)

# Primero nos quedamos con las variables continuas:

cols <- c('Valor', 'Superf', 'Edat', 'ValSol')

data <- bcn_pisos[, cols]

# Calculamos los LOF scores y los graficamos
outlier_scores <- LOF(scale(data), k=5)

plot(density(outlier_scores))

outliers_sc <- outlier_scores[outlier_scores > 1]

# Ordenamos los scores
outliers <- order(outlier_scores, decreasing=T)

# Juntamos los resultados
data_con_outliers <- cbind(OutlierScores=outlier_scores[outliers], data[outliers,])

# Identificamos los potenciales outliers (valores mayores a 1).
# Si tomamos estrictamente 1 como threshold, la mayoría de los puntos quedarían excluidos,
# por lo que necesitamos pensar en otro criterio para excluir los puntos
# Calculamos un threshold tomando como criterio la distance 3*IQR con respecto al rango intercuartílico
iqr <- as.numeric(summary(outlier_scores)[5] - summary(outlier_scores)[2])

upper_range = as.numeric(summary(outlier_scores)[5]) + 3*iqr

potential_outliers <- data_con_outliers[data_con_outliers$OutlierScores > upper_range,]

potential_outliers

# dataset sin potenciales outliers
bcn_pisos_no_outliers <- bcn_pisos[data_con_outliers$OutlierScores < upper_range, ]
bcn_pisos_no_outliers
# Out:
#      OutlierScores Valor    Superf Edat ValSol
# 163  9.731024       3283200  60.00 198   80107.40
# 112  5.966654      80126080 475.30 289  166465.75
# 162  2.972040       8450000  65.00 150  100036.25
# 1787 2.646105       6908846  86.63  10   20320.85
# 409  2.590744      67587904 182.67  60  345825.40
# 1732 2.450899      23520000 168.00  35   66821.50
# 116  2.383793       7321600  51.20 150   80107.40
# 1995 2.306762       7170080  87.44  35   26963.80
# 1139 2.287689      38354208 103.66  50  292681.80
# 1987 2.265198       6300000  63.00  53   46892.65
# 2058 2.204078      99662144 204.00  28  365754.25
# 113  2.169429      15190944 102.85 209  106679.20
# 1908 2.087557      13505100  91.56  23  106679.20
# 1156 2.022158      51175008 115.00   0  279395.90
# 441  1.985892      14602500  88.50  32   56192.78
# 793  1.930232      34800000 120.00  40  146536.90
# 434  1.865074      43290000 150.00 149  199680.50
# 1083 1.850174      18079600 129.14  33   66821.50
# 1965 1.841990       4506034  26.00  30   93393.30
# 106  1.839937      32400000 144.00 160  119965.10
# 2313 14110536 86.00  3    1     27   2_M   Planta Nou_Barris    80107.40 MANZ
# 2314  8713124 46.47  2    1     35   2_M   Planta Nou_Barris   100036.25 BLOQ
# 2315 15400000 88.00  3    1     21   3_N   Planta Nou_Barris   100036.25 BLOQ
# 2316 14762996 79.80  3    1     28   3_N   Planta Nou_Barris   113322.15 MANZ
# 2317 18450000 90.00  3    1     26   2_M   Planta Nou_Barris   126608.05 BLOQ
# 2318 15858000 88.10  3    1     30   2_M   Planta Nou_Barris   119965.10 MANZ
# 2319 18929248 94.00  4    1     31   2_M   Atic   Nou_Barris   119965.10 BLOQ
# 2320 13034000 66.50  2    1     27   4_B   Planta Nou_Barris    93393.30 MANZ
# 2321 11016000 61.20  2    1     30   3_N   Planta Nou_Barris    93393.30 MANZ
# 2322 16280000 88.00  3    1     30   2_M   Planta Nou_Barris   106679.20 BLOQ
# 2323 21381520 97.00  4    2     25   3_N   Planta Nou_Barris   119965.10 MANZ
# 2324 14784000 70.40  3    1     34   3_N   Planta Nou_Barris   119965.10 MANZ
# 2325  6353142 38.79  1    1     34   1_MM  Planta Nou_Barris   113322.15 MANZ
# 2326 11010008 57.00  2    1     40   3_N   Planta Nou_Barris   100036.25 BLOQ
# 2327 16065000 76.50  3    1     25   3_N   Planta Nou_Barris   126608.05 BLOQ
# 2328 15885000 70.60  3    1     30   3_N   Planta Nou_Barris   139893.95 MANZ
# 2329  9856000 44.80  2    1     40   3_N   Planta Nou_Barris   126608.05 MANZ
#      Ascens ExtInt Reforma
# 84   NO     EXT    REF5A10
# 85   NO     EXT    REF1A5
# 86   NO     EXT    REF1A5
# 87   NO     EXT    RECIENREF
# 88   NO     EXT    REF>20
# 89   NO     EXT    SINREFORMA
# 90   NO     EXT    REF>20
# 91   NO     INT    REF1A5
# 92   SI     EXT    SINREFORMA
# 93   NO     INT    REF1A5
# 94   NO     EXT    REF1A5
# 95   NO     EXT    REF15-20
# 96   SI     EXT    RECIENREF
# 97   NO     EXT    REF5A10
# 98   NO     EXT    REF1A5
# 99   SI     EXT    REF5A10
# 100  SI     EXT    OBRANUEVA
# 101  NO     EXT    REF1A5
# 102  NO     EXT    SINREFORMA
# 103  NO     EXT    REF1A5
# 104  SI     EXT    RECIENREF
# 105  NO     EXT    REF>20
# 106  SI     EXT    REF1A5
# 107  NO     INT    RECIENREF
# 108  NO     EXT    SINREFORMA
# 109  NO     EXT    REF1A5
# 110  NO     EXT    REF1A5
# 111  NO     EXT    REF5A10
# 112  NO     EXT    RECIENREF
# 113  NO     EXT    REF>20
# ⋮    ⋮      ⋮      ⋮
# 2298 SI     EXT    REF1A5
# 2300 NO     INT    REF1A5
# 2301 NO     EXT    REF1A5
# 2303 SI     EXT    REF10-15
# 2304 NO     EXT    REF5A10
# 2305 NO     EXT    SINREFORMA
# 2306 NO     EXT    REF5A10
# 2307 NO     EXT    REF10-15
# 2308 SI     EXT    REF1A5
# 2309 NO     EXT    REF1A5
# 2310 NO     EXT    SINREFORMA
# 2311 NO     EXT    REF1A5
# 2312 NO     EXT    REF15-20
# 2313 SI     EXT    REF5A10
# 2314 NO     EXT    SINREFORMA
# 2315 SI     EXT    REF5A10
# 2316 NO     EXT    REF1A5
# 2317 SI     EXT    REF5A10
# 2318 SI     EXT    SINREFORMA
# 2319 SI     EXT    REF5A10
# 2320 NO     INT    REF1A5
# 2321 NO     EXT    REF1A5
# 2322 SI     INT    REF1A5
# 2323 SI     INT    REF1A5
# 2324 NO     EXT    REF1A5
# 2325 NO     INT    REF15-20
# 2326 NO     EXT    REF1A5
# 2327 SI     EXT    SINREFORMA
# 2328 SI     EXT    REF1A5
# 2329 NO     INT    RECIENREF
# Plot with title “density(x = outlier_scores)”

# %% [markdown]
# #### 8. Efectúe un diagrama bivariante (plot) entre el “Valor de los pisos” y su “Superficie”. Calcule la covariancia y la correlación entre ambas variables.

# %%
# Graficamos un diagrama bivariante
plot(
  bcn_pisos_no_outliers$Valor,
  bcn_pisos_no_outliers$Superf,
  xlab="Valor",
  ylab="Superficie",
  col="orange",
  main="Valor vs Superficie")
  abline(v=mean(bcn_pisos_no_outliers$Valor), col="blue")
  abline(h=mean(bcn_pisos_no_outliers$Superf), col="red")
# Out:
# Plot with title “Valor vs Superficie”

# %%
# Calculamos la covarianza
cov_val_sup <- cov(bcn_pisos_no_outliers$Valor, bcn_pisos_no_outliers$Superf)

cat("El valor de la covarianza es: ", cov_val_sup)

# Calculamos la correlación

cor_val_sup <- cor(bcn_pisos_no_outliers$Valor, bcn_pisos_no_outliers$Superf)

cat("\nEl valor de la correlación es: ", cor_val_sup)
# Out:
# El valor de la covarianza es:  280778657
# El valor de la correlación es:  0.8811045

# %% [markdown]
# #### 9. Calcule la asociación entre el “Valor de los pisos” y el “Distrito”.

# %%
# En este caso queremos calcular la asociación entre una variable continua (Valor de los pisos) y una variable categórica (Distrito)
# Para ello realizamos el one-way analysis of mean

oneway.test(bcn_pisos_no_outliers$Valor~bcn_pisos_no_outliers$Dist,var.equal=T)

# Interpretación: dado que el p-value es cercano al cero, podemos inferir que las variables son dependientes.
# Out:
# 	One-way analysis of means
#
# data:  bcn_pisos_no_outliers$Valor and bcn_pisos_no_outliers$Dist
# F = 106.13, num df = 9, denom df = 2163, p-value < 2.2e-16

# %% [markdown]
# #### 10. Calcule la asociación entre el “Distrito” y el “Estado de la vivienda”.

# %%
# Calculamos la asociación entre dos variables categóricas: “Distrito” y el “Estado de la vivienda”,
# para ello realizamos el Pearson Chi-square test

chisq.test(bcn_pisos_no_outliers$Dist, bcn_pisos_no_outliers$Estat)

# Interpretación: dado que el p-value es cercano al cero, podemos inferir que las variables son dependientes.
# Out:
# Warning message in chisq.test(bcn_pisos_no_outliers$Dist, bcn_pisos_no_outliers$Estat):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  bcn_pisos_no_outliers$Dist and bcn_pisos_no_outliers$Estat
# X-squared = 107.67, df = 36, p-value = 4.53e-09
